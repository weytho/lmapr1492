# %%
from pymatgen.ext.matproj import MPRester
from pymatgen.io.cif import CifWriter
from pymatgen.core.lattice import Lattice
from pymatgen.symmetry.analyzer import SpacegroupAnalyzer
from pymatgen.analysis.diffraction.xrd import XRDCalculator

with MPRester("vKG3XPbn7JethOZI") as m:

    # Structure for material id
    structure_mol = m.get_structure_by_material_id("mp-9813")
    w = CifWriter(structure_mol)
    w.write_file('structure_mol.cif')
    
    #default values are a calculation using a radiation of CuKa, with the asked wave length
    calculator = XRDCalculator(symprec=0.1)
    #apply on my structure
    diff_pat = calculator.get_pattern(structure_mol)
    #plot (2 ways)
    #calculator.show_plot(structure_mol)
    diag = calculator.get_plot(structure_mol, annotate_peaks = True)
    print('X-Ray Diffraction Pattern :\n')
    diag.show()
    
    indices = diff_pat.hkls
    print('First diffraction peak :',indices[0][0]['hkl'])
    print('Second diffraction peak :',indices[1][0]['hkl'])
    print('Third diffraction peak :',indices[2][0]['hkl'])
    print('The four firsts indexes are the "hkl" indexes and the fourth on is "i" the multiplicity index')
    print('These indexes correspond to the graph provided by materials project (WS2)')
# Out:
# X-Ray Diffraction Pattern :
# First diffraction peak : (0, 0, 0, 3)
# Second diffraction peak : (0, 0, 0, 6)
# Third diffraction peak : (1, 0, -1, 1)
# The four firsts indexes are the "hkl" indexes and the fourth on is "i" the multiplicity index
# These indexes correspond to the graph provided by materials project (WS2)
